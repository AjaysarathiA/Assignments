# %%
from Assignment import Assignment

# %%
Assignment.subfields()
# Out:
# Subfields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# speech proecessing
# Natural Language Processing

# %%
Assignment.oddeven()
# Out:
# Enter the number:  52452
# the Number is Even

# %%
age=int(input("Enter your age: "))
gender=input("Enter your gender: ")
# Out:
# Enter your age:  20
# Enter your gender:  male

# %%
Assignment.eligible(age,gender)
# Out:
# not eligible

# %%
Assignment. percentage()
# Out:
# enter your mark:  98
# enter your mark:  87
# enter your mark:  95
# enter your mark:  95
# enter your mark:  93
# 98 87 95 95 93
# 468
# 93.60000000000001

# %%
Assignment.Triangle()
# Out:
# 544.0
# 10
