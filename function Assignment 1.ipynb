# %%
#Create a class and function, and list out the items in the list

# %%
class subfieldsinAI:
    def subfields():
     print("Machine Learning")
     print("Neural Networks")
     print("Vision")
     print("Robotics")
     print("specch proecessing")
     print("Natural Language Processing")

# %%
answer=subfieldsinAI.subfields()
# Out:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# specch proecessing
# Natural Language Processing

# %%
#create a function that checks the number is oddd or even

# %%
class oddeven:
 def oddeven():
   num=int(input("Enter the number: "))
   if(num%2==0):
    print("the Number is Even")
   else:
    print("the Number is Odd")

# %%
oddeven.oddeven()
# Out:
# Enter the number:  5
# the Number is Odd

# %%
# Create a function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female

# %%
class EligiblityForMarriage:
 def eligible(age,gender):
    if gender.lower()=="male" and age>=21:
     print("Eligible for marriage")
    elif gender.lower()=="female" and age>=18:
     print("Eligible for marriage")
    else:
        print("not eligible")

# %%
age=int(input("Enter your age: "))
gender=input("Enter your gender: ")
EligiblityForMarriage.eligible(age,gender)
# Out:
# Enter your age:  17
# Enter your gender:  female
# not eligible

# %%
#calculate the percentage of your 10th mark

# %%
class FindPercent:
    def percentage():
        sub1=int(input("enter your mark: "))
        sub2=int(input("enter your mark: "))
        sub3=int(input("enter your mark: "))
        sub4=int(input("enter your mark: "))
        sub5=int(input("enter your mark: "))
        print(sub1,sub2,sub3,sub4,sub5)
        Total=sub1+sub2+sub3+sub4+sub5
        print(Total)
        percentage=Total/500*100
        return percentage

# %%
 FindPercent.percentage()
# Out:
# enter your mark:  95
# enter your mark:  95
# enter your mark:  95
# enter your mark:  100
# enter your mark:  100
# 95 95 95 100 100
# 485
# 97.0

# %%
#print area and perimeter of triangle using class and functions

# %%
class Triangle:
    def area(height,breadth):
        return (height*breadth)/2
    def perimeter(height1,height2,breadth):
        return (height1+height2+breadth)

# %%
print("area: ",Triangle.area(2,4))
print("perimeter: ",Triangle.perimeter(2,3,4))
# Out:
# area:  4.0
# perimeter:  9
